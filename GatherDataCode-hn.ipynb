# %%
# importing google_images_download module 
from bing_image_downloader import downloader
  
search_queries = [       
# '1820 fashion clothing', '1830 fashion clothing', 
# '1840 fashion clothing', '1850 fashion clothing', 
# '1860 fashion clothing', '1870 fashion clothing', 
# '1880 fashion clothing', '1890 fashion clothing',
# '1900 fashion clothing', '1910 fashion clothing', 
# '1920 fashion clothing', '1925 fashion clothing', 
# '1930 fashion clothing', '1935 fashion clothing', 
# '1940 fashion clothing', '1945 fashion clothing', 
'1950 fashion clothing', '1955 fashion clothing', 
'1960 fashion clothing', '1965 fashion clothing',
'1970 fashion clothing', '1975 fashion clothing', 
'1980 fashion clothing', '1985 fashion clothing',
'1990 fashion clothing', '1995 fashion clothing', 
'2000 fashion clothing', '2005 fashion clothing',
'2010 fashion clothing', '2015 fashion clothing', 
'2020 fashion clothing' ] 

redo = ['2020 fashion clothing']
  
def downloadimages(query): 
    
    try: 
        downloader.download(query,  limit=60, output_dir='imagesUPDATED') 
      
    # Handling File NotFound Error     
    except FileNotFoundError:  
        # Providing arguments for the searched query 
        try: 
            # Downloading the photos based 
            # on the given arguments 
            downloader.download(query,  limit=60, output_dir='imagesUPDATED') 
        except: 
            pass
  
# Driver Code 
for query in search_queries: 
    downloadimages(query)  
    print()
# Out:
# [!!]Indexing page: 1
#
# [%] Indexed 12 Images on Page 1.
#
# ...
#
# [%] Downloading Image #1 from https://fiftiesweb.com/wordpress/wp-content/uploads/2015/06/teen-sodafountain.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #2 from https://www.thestateofthearts.co.uk/wp-content/uploads/2017/10/June-modelling-a-tailored-wool-suit-holding-the-brim-of-her-picture-hat-about-1951-52-location-and-photographer-unknown-2.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #3 from https://static.topvintage.net/shop-product/107371-Bunny-Kay-Polkadot-in-Pink-134-29-21114-20170120-01W-full.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #4 from https://3.bp.blogspot.com/-wc-qWWJljSM/UPaQLjrBemI/AAAAAAACQyw/l9BI7GgdZtM/s640/Fashion+Magazine+Covers+from+1940s-1950s+(37).jpg
# [%] File Downloaded !
#
# [%] Downloading Image #5 from http://menscraze.com/wp-content/uploads/2016/05/1950s-Men-Hairstyles.jpg
# [%] File Downloaded !
#
# ...
