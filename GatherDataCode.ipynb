# %%
# importing google_images_download module 
from bing_image_downloader import downloader
import os

# %%
cwd = os.getcwd()
print(cwd)
# Out:
# C:\Users\18025\Documents\GitHub\Fashion-throughout-the-Years

# %%
search_queries = ['2020 dresses', '2020 street style', '2020 fashion', '2020 fashion trends'] 
  
  
def downloadimages(query): 
    
    try: 
        downloader.download(query,  limit=20, output_dir='prediction_Images2020') 
      
    # Handling File NotFound Error     
    except FileNotFoundError:  
        # Providing arguments for the searched query 
        try: 
            # Downloading the photos based 
            # on the given arguments 
            downloader.download(query,  limit=20, output_dir='prediction_Images2020') 
        except: 
            pass
# Driver Code 
for query in search_queries: 
    downloadimages(query)  
    print()
# Out:
# [!!]Indexing page: 1
#
# [%] Indexed 12 Images on Page 1.
#
# ...
#
# [%] Downloading Image #1 from https://ohbestdayever.com/wp-content/uploads/2018/06/elegant-fall-wedding-cake-for-2018.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #2 from https://i.pinimg.com/736x/e3/27/4d/e3274dafa8577537dd3dc78d453f9c5a--castle-homes-castle-interiors.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #3 from https://emmalovesweddings.com/wp-content/uploads/2018/11/trending-wedding-bouquet-ideas-with-sunset-orange-colors.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #4 from https://www.newstyledress.com/media/catalog/product/2/0/2020_wedding_jumpsuits_disassemble_bride_sweetheart_dress_suits.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #5 from https://theviraler.com/wp-content/uploads/2020/05/Amy-Macdonald-hot-blue-look.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #6 from https://www.himisspuff.com/wp-content/uploads/2017/10/Hanging-lantern-wedding-decor-33.jpg
# ...
